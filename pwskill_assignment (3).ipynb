# %% [markdown]
# #1. What is Python, and why is it popular?

# %% [markdown]
# #Python is a high-level, easy-to-learn programming language. It is popular because of its simple syntax, large libraries, and fast development.

# %% [markdown]
# #2. What is an interpreter in Python?

# %% [markdown]
# #An interpreter executes Python code line by line.

# %% [markdown]
# #3. What are pre-defined keywords in Python?

# %% [markdown]
# #Keywords are reserved words in Python that have special meaning (like if, for, while, class)

# %% [markdown]
# #4. Can keywords be used as variable names?

# %% [markdown]
# #No, keywords cannot be used as variable names.

# %% [markdown]
# #5. What is mutability in Python?

# %% [markdown]
# #Mutability means an object can be changed after creation.

# %% [markdown]
# #6. Why are lists mutable but tuples are immutable?

# %% [markdown]
# #Lists can be modified, but tuples cannot be changed once created.

# %% [markdown]
# #7. What is the difference between == and is operator in Python?

# %% [markdown]
# #is compares memory location (object identity)*******

# %% [markdown]
# #8. What are logical operators in Python?

# %% [markdown]
# #logical opeerator are and, or, not in pyhton

# %% [markdown]
# #9. What is type casting in Python?

# %% [markdown]
# #Converting one data type into another (like int(), float(), str()).

# %% [markdown]
# #10. What is the difference between implicit and explicit type casting?

# %% [markdown]
# #Implicit: Python converts automatically.
# #Explicit: Programmer converts manually

# %% [markdown]
# #11. What is the purpose of conditional statements in Python?

# %% [markdown]
# #To make decisions using if, elif, and else.

# %% [markdown]
# #12. How does the elif statement work?

# %% [markdown]
# #It checks a condition; if true, the code block runs; otherwise, it is skipped.

# %% [markdown]
# #13. What is the difference between for and while loops?

# %% [markdown]
# #for loop is used for a fixed sequence or range.
# #while loop runs until a condition becomes false.

# %% [markdown]
# #14. Describe a scenario where a while loop is more suitable than a for loop.

# %% [markdown]
# #When the number of iterations is unknown, like taking user input until a valid value is entered.

# %% [markdown]
# PRATICAL QWESTION:

# %%
#1.Write a Python program to print "Hello, World!"
print("hello world!")
# Out:
# hello world!

# %%
#2. Write a Python program that displays your name and age

name = "Raj Ranjan"
age = 22
print("My name is", name)
print("My age is", age)
# Out:
# My name is Raj Ranjan
# My age is 22

# %%
#3. Write code to print all the pre-defined keywords in Python using the keyword library

import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#4. Write a program that checks if a given word is a Python keyword.

import keyword

word = input("Enter a word: ")

if word in keyword.kwlist:
    print(word, "is a Python keyword")
else:
    print(word, "is NOT a Python keyword")
# Out:
# Enter a word: cntrl
# cntrl is NOT a Python keyword

# %%
#5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each

# List
my_list = [10, 32, 23]
my_list[0] = 10  # Allowed

# Tuple
my_tuple = (12, 332, 3333)


print("List:", my_list)
print("Tuple:", my_tuple)
# Out:
# List: [10, 32, 23]
# Tuple: (12, 332, 3333)

# %%
#6. Write a function to demonstratethe behaviour  mutable and immutable argument
def demo(a, b):
    a += 1
    b.append(4)

x = 5
y = [1,2]

demo(x, y)

print(x)
print(y)
# Out:
# 5
# [1, 2, 4]

# %%
#7. Write a program that performs basic arithmetic operations on two user input numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Quotient:", a / b)
# Out:
# Enter first number: 7
# Enter second number: 6
# Sum: 13
# Difference: 1
# Product: 42
# Quotient: 1.1666666666666667

# %%
#8. Write a program to demonstrates the use of logical operators

a = 5
b = 10

print(a < 5and b > 5)
print(a == 5 or b == 5)
print(not (a > b))
# Out:
# False
# True
# True
# <>:6: SyntaxWarning: invalid decimal literal
# <>:6: SyntaxWarning: invalid decimal literal
# /tmp/ipython-input-844316531.py:6: SyntaxWarning: invalid decimal literal
#   print(a < 5and b > 5)

# %%
#9.write a python program to convert user input from string to integer ,float and boolean types.

x = input("Enter value: ")

print(int(x))
print(float(x))
print(True if x.lower() == "true" else False)
# Out:
# Enter value: 4
# 4
# 4.0
# False

# %%
#10. Write code to demonstrate typ casting with list elements

my_list = [103, 320, 304, 440, 50]
print(my_list)
# Out:
# [103, 320, 304, 440, 50]

# %%
#11. Write a prog  that checks if a number is positive, negative, or zero

num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 55
# Positive

# %%
#12. Write a for loop to print numbers from 1 to 10

for i in range(98, 101):
    print(i)
# Out:
# 98
# 99
# 100

# %%
#13. Write a Python program to find the sum of all even numbers between 1 and 50

total = 5
for i in range(1, 22):
    if i % 2 == 0:
        total += i

print("Sum of even numbers:", total)
# Out:
# Sum of even numbers: 115

# %%
#14. Write a program to reverse a string using a while loop

s = input("Enter a string: ")
rev = ""
i = len(s) - 1

while i >= 0:
    rev += s[i]
    i -= 1

print("Reversed:", rev)
# Out:
# Enter a string: "rahul"
# Reversed: "luhar"

# %%
#15. Write a Python program to calculate the factorial of a number provided by the user using a while loop

num = int(input("Enter a number: "))
fact = 1
i = 1

while i <= num:
    fact *= i
    i += 1

print("Factorial:", fact)
# Out:
# Enter a number: 55
# Factorial: 12696403353658275925965100847566516959580321051449436762275840000000000000
